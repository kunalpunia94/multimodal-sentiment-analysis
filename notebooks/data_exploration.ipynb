# %% [markdown]
# # Multimodal Emotion Recognition (CREMA-D)
# Replaced notebook with your provided end-to-end pipeline code.

# %%
import matplotlib.pyplot as plt

columns = ["statement", "emotion", "intensity", "gender"]

for col in columns:
    print(f"\n================ {col.upper()} ================")
    print("Unique Values:")
    print(df[col].unique())

    print("\nValue Counts:")
    print(df[col].value_counts())

    plt.figure()
    df[col].value_counts().plot(kind="bar")
    plt.title(f"Count Plot of {col}")
    plt.xlabel(col)
    plt.ylabel("Count")
    plt.xticks(rotation=45)
    plt.show()

    plt.figure()
    df[col].value_counts().plot(kind="pie", autopct="%1.1f%%")
    plt.title(f"Pie Chart of {col}")
    plt.ylabel("")
    plt.show()
